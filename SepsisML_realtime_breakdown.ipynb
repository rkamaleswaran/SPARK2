# %% [markdown]
# # Sepsis ML Real Time Implementation
# Jupyter notebook created to display sepsis_ml_run.py

# %%
# import all libraries
import sepsis_ml as ml
import numpy as np
import pandas as pd
import argparse
import logging
from datetime import datetime, timedelta
import requests
from requests.auth import HTTPBasicAuth
import json
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
pd.options.display.float_format = '{:,.4f}'.format

# %%
# will not print the following columns to this notebook due to PHI
hide = ["csn", "pat_id", "age", "is_Female", "is_asian", "is_white", "is_black", "is_other", "hospital_discharge_date_time", "hospital_admission_date_time"]

# %% [markdown]
# ## API Connection Helper Functions

# %%
# GET API Call
def connect(url, username, password):
    response = requests.get(url,auth=HTTPBasicAuth(username, password), verify=True)
    data = json.loads(response.content)
    
    hasMore = data["hasMore"]
    offset = data["offset"]

    df = pd.DataFrame(data['items'])
   
    while hasMore:
        querystring = {"offset": offset+ 1000}
        response = requests.get(url,auth=HTTPBasicAuth(username, password), verify=True, params = querystring)
        data = json.loads(response.content)

        hasMore = data["hasMore"]
        offset = data["offset"]

        df = pd.concat([df,pd.DataFrame(data['items'])])

    return df

# %%
# POST API Call
def upload(url, username, password, output):
    response = requests.post(url,headers={"Content-Type":"application/json"},auth=HTTPBasicAuth(username, password), data = output)
    print(response)

# %%
def select_process_data(test_data, current_time):
    
    # 1) filter only encounters within 48 hour from current time
    final_test = test_data.copy()
    
    final_test.loc[:,"keep"] = (current_time - final_test["hospital_admission_date_time"]).dt.total_seconds()/3600
    keep_csns_filter1 = final_test.loc[final_test["keep"] <= 49].csn.unique()
    final_test = final_test[final_test["csn"].isin(keep_csns_filter1)]
    
    # 2) filter data within 0-48 hour since admission
    final_test["keep"] = (final_test["recorded_time"] - final_test["hospital_admission_date_time"]).dt.total_seconds()/3600.0
    final_test["keep"] = (final_test["keep"] <=49) & (final_test["keep"] >= 0)
    final_test = final_test.copy()
    final_test = final_test.loc[final_test.keep, :].reset_index(drop = True)
    final_test.drop(["keep"], axis = 1, inplace = True)
    
    return final_test

# %%
total_feature_list = ['HR','O2Sat','Temp','SBP','DBP','MAP','Resp','EtCO2',\
                'AST','Alkalinephos','BUN','BaseExcess','Bilirubin_total',\
                'Calcium','Chloride','Creatinine','FiO2','Glucose',\
                'HCO3','Hct','Hgb','Lactate','Magnesium',\
                'PTT', 'PaCO2','PaO2','Phosphate','Platelets','Potassium',\
                'SaO2','Sodium','WBC','pH',\
                'gcs_total_score','age','is_female',\
                'HR_interval_f1','HR_interval_f2','HR_diff',\
                'O2Sat_interval_f1','O2Sat_interval_f2','O2Sat_diff',\
                'Temp_interval_f1','Temp_interval_f2','Temp_diff',\
                'SBP_interval_f1','SBP_interval_f2','SBP_diff',\
                'MAP_interval_f1','MAP_interval_f2','MAP_diff',\
                'DBP_interval_f1','DBP_interval_f2','DBP_diff',\
                'Resp_interval_f1','Resp_interval_f2','Resp_diff',\
                'EtCO2_interval_f1','EtCO2_interval_f2','EtCO2_diff',\
                'AST_interval_f1','AST_interval_f2','AST_diff',\
                'Alkalinephos_interval_f1','Alkalinephos_interval_f2','Alkalinephos_diff',\
                'BUN_interval_f1','BUN_interval_f2','BUN_diff',\
                'BaseExcess_interval_f1','BaseExcess_interval_f2','BaseExcess_diff',\
                'Bilirubin_total_interval_f1','Bilirubin_total_interval_f2','Bilirubin_total_diff',\
                'Calcium_interval_f1','Calcium_interval_f2','Calcium_diff',\
                'Chloride_interval_f1','Chloride_interval_f2','Chloride_diff',\
                'Creatinine_interval_f1','Creatinine_interval_f2','Creatinine_diff',\
                'FiO2_interval_f1','FiO2_interval_f2','FiO2_diff',\
                'Glucose_interval_f1','Glucose_interval_f2','Glucose_diff',\
                'HCO3_interval_f1','HCO3_interval_f2','HCO3_diff',\
                'Hct_interval_f1','Hct_interval_f2','Hct_diff',\
                'Hgb_interval_f1','Hgb_interval_f2','Hgb_diff',\
                'Lactate_interval_f1','Lactate_interval_f2','Lactate_diff',\
                'Magnesium_interval_f1','Magnesium_interval_f2','Magnesium_diff',\
                'PTT_interval_f1','PTT_interval_f2','PTT_diff',\
                'PaCO2_interval_f1','PaCO2_interval_f2','PaCO2_diff',\
                'PaO2_interval_f1','PaO2_interval_f2','PaO2_diff',\
                'Phosphate_interval_f1','Phosphate_interval_f2','Phosphate_diff',\
                'Platelets_interval_f1','Platelets_interval_f2','Platelets_diff',\
                'Potassium_interval_f1','Potassium_interval_f2','Potassium_diff',\
                'SaO2_interval_f1','SaO2_interval_f2','SaO2_diff',\
                'Sodium_interval_f1','Sodium_interval_f2','Sodium_diff',\
                'WBC_interval_f1','WBC_interval_f2','WBC_diff',\
                'pH_interval_f1','pH_interval_f2','pH_diff',\
                'HR_mean','O2Sat_mean','SBP_mean','MAP_mean','Resp_mean',\
                'HR_median','O2Sat_median','SBP_median','MAP_median','Resp_median',\
                'HR_min','O2Sat_min','SBP_min','MAP_min','Resp_min',\
                'HR_max','O2Sat_max','SBP_max','MAP_max','Resp_max',\
                'HR_std','O2Sat_std','SBP_std','MAP_std','Resp_std',\
                'HR_dstd','O2Sat_dstd','SBP_dstd','MAP_dstd','Resp_dstd',\
                'HR_score','Temp_score','Resp_score','MAP_score','Creatinine_score','qsofa','Platelets_score','Bilirubin_score','SIRS']

# %%
def get_hist_data(test_data, current_time):
    
    hist_data = test_data.copy()
    hist_data["past_time"] = (current_time - hist_data["recorded_time"]).dt.total_seconds()/3600
    
    g= total_feature_list[:34]
   
    hist_data[g] = hist_data[g].notnull().astype('int')

    t = hist_data["past_time"].values
    t = np.vstack([t]*len(g))

    hist_data[g] = np.where(hist_data[g] == 1, np.transpose(t), hist_data[g])

    hist_data.replace(0, np.nan, inplace = True)
    
    hist_data[g] = hist_data.groupby(by = ["csn", "pat_id"])[g].fillna(method = 'ffill')
    
    hist_data.drop_duplicates(subset = ["csn", "pat_id"], keep = "last", inplace = True)
    
    add_cols = total_feature_list[34:]
    
    nan_df = pd.DataFrame(columns = add_cols)
    hist_data = pd.concat([hist_data, nan_df], axis =1)
    hist_data.iloc[:,3:] = round(hist_data.iloc[:,3:],3)
    
    return hist_data

# %%
def run(test_data):
    
    dtypes = {"pat_id": int, "csn": int, "HR": float, "O2Sat": float, "Temp": float, 
             "SBP": float, "DBP": float, "Resp": float, "EtCO2": float, 
             "AST": float, "Alkalinephos": float, "BUN": float, "BaseExcess": float,
             "Bilirubin_total": float, "Calcium": float, "Creatinine": float,
             "FiO2": float, "Glucose": float, "HCO3": float, "Hct": float, 
             "Hgb": float, "Lactate": float, "Magnesium": float, "PTT": float,
             "PaCO2": float, "PaO2": float, "Phosphate": float, "Platelets": float,
             "Potassium": float, "SaO2": float, "Sodium": float, "WBC": float,
             "pH": float, "gcs_total_score": float, "age": float, "gender": int}
    
    #test_data = pd.read_csv(test_data_path, dtype = dtypes, parse_dates= ["recorded_time", "hospital_admission_date_time"])
    
    thresh = {"HR": (0,250),
                 "O2Sat": (0,100),
                 "Temp": (25,45),
                 "SBP": (0,260),
                 "DBP": (0, 220),
                 "MAP": (0,260),
                 'Resp': (0,80),
                 'EtCO2': (0, 60),
                  "pH": (6.7, 8),
                  "PaCO2": (15, 150),
                  "SaO2": (0,100),
                  "AST": (0, 10000),
                  "BUN": (0,200),
                  "Alkalinephos": (0, 10000),
                  "Calcium": (0,20),
                  "Chloride": (60,150),
                  "Creatinine": (0, 15),
                  "Glucose": (0, 1200),
                  "Lactate": (0,20),
                  "Magnesium": (0,10), 
                  "Phosphate": (0,20),
                  "Potassium": (0,10),
                  "Bilirubin_total": (0,30),
                  "Hct": (0, 75),
                   "Hgb": (0,25),
                   "PTT": (0,150),
                   "WBC": (0,150),
                   "Platelets": (0,1000)}

    test_data = ml.data_clean(test_data, thresh)
    
    variables = total_feature_list[:34]
    
    demographics = ["pat_id", "csn", "age", "is_female"]
    
    stat = test_data[demographics].drop_duplicates()
    
    test_data = test_data.drop(["age", "is_female"], axis = 1)
    
    test_data = ml.resampling(test_data)
    test_data = test_data.groupby(["pat_id", "csn"]).apply(lambda v: ml.rolling_overlap(v, 6, variables, 3))
    test_data = test_data.drop(["pat_id", "csn"], axis = 1).reset_index(drop = False).rename(columns = {"level_2" : "los"})
    test_data = test_data.merge(stat, on = ["pat_id", "csn"], how = "left")
  
    return test_data

# %% [markdown]
# # Main Function

# %% [markdown]
# ## 1. Preprocess

# %% [markdown]
# ### 1.0 Read Data

# %%
# getting current time
current_time = pd.to_datetime(str(pd.Timestamp.now())[:-7])
print(current_time)
# Out:
# 2022-08-13 22:27:36

# %%
# credidentials for API
username = 'Sepsis_ML'
password = 'jfVDS756F$jkf&@*'

# receive input data with GET
url = 'https://prd-rta-app01.eushc.org:8443/ords/rta/sepsisml/derivedcache'
test_data = connect(url, username, password)
    
print("completed reading")

# %%
test_data = pd.read_csv("sample_from_API_GET.csv")

# %%
test_data.iloc[:,-4:]
# Out:
#               display  result_val      valid_from_dt_tm     event_start_dt_tm
# 0          Heart Rate    101.0000  2022-08-12T23:38:35Z  2022-08-12T22:00:00Z
# 1          Heart Rate    102.0000  2022-08-12T23:38:35Z  2022-08-12T23:00:00Z
# 2          Heart Rate    106.0000  2022-08-13T00:17:32Z  2022-08-13T00:16:00Z
# 3          Heart Rate    107.0000  2022-08-13T03:03:50Z  2022-08-13T00:00:00Z
# 4          Heart Rate    104.0000  2022-08-13T03:03:50Z  2022-08-13T01:00:00Z
# ...               ...         ...                   ...                   ...
# 4995        MAP, Cuff     73.0000  2022-08-13T04:10:53Z  2022-08-13T04:06:00Z
# 4996        MAP, Cuff     65.0000  2022-08-13T07:40:33Z  2022-08-13T07:37:00Z
# 4997        MAP, Cuff     77.0000  2022-08-13T12:12:35Z  2022-08-13T12:11:00Z
# 4998        MAP, Cuff     83.0000  2022-08-13T15:52:15Z  2022-08-13T15:51:00Z
# 4999  Temperature (C)     36.7000  2022-08-12T22:14:11Z  2022-08-12T22:13:00Z
#
# [5000 rows x 4 columns]

# %%
# convert name mapping used in later step
sepsis_ml_map = pd.read_csv("sepsis_ml_map.csv")
sepsis_ml_map = sepsis_ml_map[["Category", "event_cd"]]
sepsis_ml_map
# Out:
#            Category    event_cd
# 0               PTT     1513062
# 1               PTT     1513062
# 2           Calcium     1514676
# 3           Calcium     1514676
# 4         Magnesium   257696134
# 5         Magnesium   257696134
# 6               AST     1514885
# 7        BaseExcess   116559600
# 8              HCO3   665495419
# 9              HCO3   665486990
# 10             HCO3   665486994
# 11             HCO3   668023039
# 12             HCO3   665486994
# 13  Bilirubin_total     1512680
# 14            PaCO2   116558758
# 15            PaCO2   668022811
# 16            PaCO2   665492721
# 17            PaCO2   665486922
# 18            PaCO2     1513281
# 19            PaCO2   116558758
# 20            PaCO2   668022811
# 21            PaCO2   665492721
# 22            PaCO2   665486922
# 23            PaCO2     1513281
# 24         Chloride     1514550
# 25       Creatinine     1514422
# 26          Glucose     1513981
# 27          Lactate  1291847774
# 28          Lactate   749082270
# 29          Lactate     1516153
# 30             PaO2   665486946
# 31             PaO2     1513205
# 32             PaO2   665486958
# 33             PaO2   668022817
# 34             PaO2   651859059
# 35             PaO2   116559099
# 36             SaO2   116559775
# 37             SaO2     1513337
# 38             SaO2   651859079
# 39             SaO2   665487086
# 40               pH   665490931
# 41               pH   668022776
# 42               pH   665490849
# 43               pH     1513254
# 44               pH   116558557
# 45        Phosphate     1513243
# 46        Potassium     1513627
# 47           Sodium     1513370
# 48              BUN     1514698
# 49             FiO2   749082182
# 50             FiO2   665490260
# 51             FiO2     1516149
# 52       Fibrinogen     1514115
# 53              Hct     1513888
# 54              Hct     1513889
# 55              WBC     1512214
# 56              WBC     1512212
# 57     Alkalinephos     1514923
# 58              Hgb     1513807
# 59              Hgb   665487054
# 60              Hgb   651859087
# 61              Hgb   668023059
# 62              Hgb     1513817
# 63              Hgb   665487058
# 64        Platelets     1513222
# 65        Platelets     1513110
# 66        Platelets  1193690901
# 67  gcs_total_score     2227158
# 68            EtCO2     1516159
# 69            EtCO2     2226304
# 70             Temp   380902603
# 71               HR    10111319
# 72            O2Sat     1516150
# 73            O2Sat      671045
# 74             Resp      671042
# 75         SBP_Cuff      671802
# 76              SBP   394037800
# 77         DBP_Cuff      671811
# 78              DBP   394037811
# 79         MAP_Cuff   268390711
# 80              MAP   394037823

# %% [markdown]
# ### 1.1 Clean Data
# - column name changes
# - convert numerics, datetime
# - filter only <= 48 hour data since hospital admission

# %%
# renaming
test_data = test_data.rename(columns = {"person_id": "pat_id", "encntr_id": "csn",
                                            "gender_disp": "is_female",
                                            "arrive_dt_tm": "hospital_admission_date_time",
                                            "event_start_dt_tm": "recorded_time"})

# convert days to ET but w/o time zone
for col in ["recorded_time", "hospital_admission_date_time", "birth_dt_tm"]:
    test_data[col] = pd.to_datetime(test_data[col]).dt.tz_convert('US/Eastern')
    test_data[col] = test_data[col].dt.tz_localize(None)
# convert numeric values
test_data["result_val"] = pd.to_numeric(test_data["result_val"], errors='coerce')
test_data["pat_id"] = pd.to_numeric(test_data["pat_id"], errors='coerce')
test_data["csn"] = pd.to_numeric(test_data["csn"], errors='coerce')

# %%
# filter only 48 hour data
test_data  = select_process_data(test_data, current_time)

# %% [markdown]
# ### 1.2 Pivot Columns

# %%
# derive age
test_data["age"] = np.floor((test_data["hospital_admission_date_time"] - test_data["birth_dt_tm"]).dt.total_seconds() / (60 * 60 * 24 * 365))


### STATIC DATA EXTRACTION ###
static = test_data[["csn", "pat_id", "is_female", "hospital_admission_date_time","age"]].copy()
static = static.drop_duplicates()
static.loc[~(static["is_female"].isin(["Female", "Male"])), "is_female"] = np.nan
static["is_female"] = static["is_female"].replace({"Female": 1, "Male" : 0}).fillna(-1)

    
### LONGITUDINAL DATA EXTRACTION ###
test_data = test_data.merge(sepsis_ml_map, on = "event_cd", how = "left")
test_data = test_data.pivot_table(index=['csn', "pat_id", "recorded_time"], columns='Category', values='result_val')
test_data = test_data.reset_index()

# %%
test_data = test_data.merge(static, on = ["csn", "pat_id"], how = "left")
    
for c in list(sepsis_ml_map.Category.unique()):
    if not (c in test_data.columns): 
        test_data[c] = np.nan
            
            
# Priority given to line measurements

test_data["SBP"] = test_data["SBP"].fillna(test_data["SBP_Cuff"])
test_data["MAP"] = test_data["MAP"].fillna(test_data["MAP_Cuff"])
test_data["DBP"] = test_data["DBP"].fillna(test_data["DBP_Cuff"])

# %%
test_data.loc[:, ~test_data.columns.isin(hide)].head(5)
# Out:
#         recorded_time  AST  Alkalinephos     BUN  Bilirubin_total  Calcium  \
# 0 2022-08-12 15:22:00  nan           nan     nan              nan      nan
# 1 2022-08-12 15:30:00  nan           nan     nan              nan      nan
# 2 2022-08-12 16:16:00  nan           nan     nan              nan      nan
# 3 2022-08-12 21:55:00  nan           nan     nan              nan      nan
# 4 2022-08-12 23:58:00  nan           nan 10.0000              nan   8.6000
#
#    Chloride  Creatinine  DBP_Cuff  EtCO2  Glucose  HCO3      HR     Hct  \
# 0       nan         nan   92.0000    nan      nan   nan 89.0000     nan
# 1       nan         nan       nan    nan      nan   nan     nan     nan
# 2       nan         nan   85.0000    nan      nan   nan 83.0000     nan
# 3       nan         nan   80.0000    nan      nan   nan 86.0000     nan
# 4  105.0000      0.8900       nan    nan 131.0000   nan     nan 36.3000
#
#       Hgb  MAP_Cuff  Magnesium    O2Sat  PTT  PaCO2  PaO2  Phosphate  \
# 0     nan  114.0000        nan 100.0000  nan    nan   nan        nan
# 1     nan       nan        nan      nan  nan    nan   nan        nan
# 2     nan  107.0000        nan  96.0000  nan    nan   nan        nan
# 3     nan   99.0000        nan 100.0000  nan    nan   nan        nan
# 4 11.5000       nan        nan      nan  nan    nan   nan        nan
#
#    Platelets  Potassium    Resp  SBP_Cuff   Sodium    Temp    WBC  \
# 0        nan        nan 16.0000  159.0000      nan 36.6000    nan
# 1        nan        nan     nan       nan      nan     nan    nan
# 2        nan        nan 17.0000  153.0000      nan 36.7000    nan
# 3        nan        nan 16.0000  138.0000      nan 37.3000    nan
# 4   369.0000     4.2000     nan       nan 137.0000     nan 7.2000
#
#    gcs_total_score  pH  is_female  BaseExcess  Lactate  SaO2  FiO2  \
# 0              nan nan          0         nan      nan   nan   nan
# 1          15.0000 nan          0         nan      nan   nan   nan
# 2              nan nan          0         nan      nan   nan   nan
# 3              nan nan          0         nan      nan   nan   nan
# 4              nan nan          0         nan      nan   nan   nan
#
#    Fibrinogen      SBP     DBP      MAP
# 0         nan 159.0000 92.0000 114.0000
# 1         nan      nan     nan      nan
# 2         nan 153.0000 85.0000 107.0000
# 3         nan 138.0000 80.0000  99.0000
# 4         nan      nan     nan      nan

# %% [markdown]
# ## (Only for RealTime) Extract last known values for later use

# %%
temp_test_data = test_data.loc[:,["pat_id", "csn", "recorded_time"] + total_feature_list[:34]].copy()

# %%
hist_data = get_hist_data(temp_test_data, current_time).reset_index(drop = True)

# %%
hist_data.loc[:, ~hist_data.columns.isin(hide)].head(5)
# Out:
#         recorded_time      HR   O2Sat    Temp     SBP     DBP     MAP    Resp  \
# 0 2022-08-13 12:27:00 10.0100 10.0100 10.0100 10.0100 10.0100 10.0100 10.0100
# 1 2022-08-13 11:20:00 11.1270 11.1270 11.1270 11.1270 11.1270 11.1270 11.1270
# 2 2022-08-13 12:07:00 10.3430 10.3430 10.3430 10.3430 10.3430 10.3430 10.3430
# 3 2022-08-13 08:30:00 13.9600 13.9600 13.9600 13.9600 13.9600 13.9600 13.9600
# 4 2022-08-13 14:15:00  8.2100  8.2100  8.2100  8.2100  8.2100 13.6600  8.2100
#
#     EtCO2  AST  Alkalinephos     BUN  BaseExcess  Bilirubin_total  Calcium  \
# 0     nan  nan           nan 18.2100         nan              nan  18.2100
# 1     nan  nan           nan 18.3770         nan              nan  18.3770
# 2 10.3430  nan           nan     nan         nan              nan      nan
# 3     nan  nan           nan     nan         nan              nan      nan
# 4     nan  nan           nan 13.7100         nan              nan  13.7100
#
#    Chloride  Creatinine  FiO2  Glucose  HCO3     Hct     Hgb  Lactate  \
# 0   18.2100     18.2100   nan  18.2100   nan 18.2100 18.2100      nan
# 1   18.3770     18.3770   nan  18.3770   nan 18.3770 18.3770      nan
# 2       nan     16.0930   nan      nan   nan     nan     nan      nan
# 3       nan         nan   nan      nan   nan     nan     nan      nan
# 4   13.7100     13.7100   nan  13.7100   nan 13.7100 13.7100      nan
#
#    Magnesium  PTT  PaCO2  PaO2  Phosphate  Platelets  Potassium  SaO2  Sodium  \
# 0    18.2100  nan    nan   nan    18.2100    18.2100    18.2100   nan 18.2100
# 1    18.3770  nan    nan   nan    18.3770    18.3770    18.3770   nan 18.3770
# 2    16.0930  nan    nan   nan        nan        nan    16.0930   nan     nan
# 3        nan  nan    nan   nan        nan        nan        nan   nan     nan
# 4    13.7100  nan    nan   nan        nan    13.7100    13.7100   nan 13.7100
#
#       WBC  pH  gcs_total_score  past_time is_female HR_interval_f1  \
# 0 18.2100 nan          30.9600    10.0100       NaN            NaN
# 1 18.3770 nan              nan    11.1270       NaN            NaN
# 2     nan nan              nan    10.3430       NaN            NaN
# 3     nan nan              nan    13.9600       NaN            NaN
# 4 13.7100 nan              nan     8.2100       NaN            NaN
#
#   HR_interval_f2 HR_diff O2Sat_interval_f1 O2Sat_interval_f2 O2Sat_diff  \
# 0            NaN     NaN               NaN               NaN        NaN
# 1            NaN     NaN               NaN               NaN        NaN
# 2            NaN     NaN               NaN               NaN        NaN
# 3            NaN     NaN               NaN               NaN        NaN
# 4            NaN     NaN               NaN               NaN        NaN
#
#   Temp_interval_f1 Temp_interval_f2 Temp_diff SBP_interval_f1 SBP_interval_f2  \
# 0              NaN              NaN       NaN             NaN             NaN
# 1              NaN              NaN       NaN             NaN             NaN
# 2              NaN              NaN       NaN             NaN             NaN
# 3              NaN              NaN       NaN             NaN             NaN
# 4              NaN              NaN       NaN             NaN             NaN
#
#   SBP_diff MAP_interval_f1 MAP_interval_f2 MAP_diff DBP_interval_f1  \
# 0      NaN             NaN             NaN      NaN             NaN
# 1      NaN             NaN             NaN      NaN             NaN
# 2      NaN             NaN             NaN      NaN             NaN
# 3      NaN             NaN             NaN      NaN             NaN
# 4      NaN             NaN             NaN      NaN             NaN
#
#   DBP_interval_f2 DBP_diff Resp_interval_f1 Resp_interval_f2 Resp_diff  \
# 0             NaN      NaN              NaN              NaN       NaN
# 1             NaN      NaN              NaN              NaN       NaN
# 2             NaN      NaN              NaN              NaN       NaN
# 3             NaN      NaN              NaN              NaN       NaN
# 4             NaN      NaN              NaN              NaN       NaN
#
#   EtCO2_interval_f1 EtCO2_interval_f2 EtCO2_diff AST_interval_f1  \
# 0               NaN               NaN        NaN             NaN
# 1               NaN               NaN        NaN             NaN
# 2               NaN               NaN        NaN             NaN
# 3               NaN               NaN        NaN             NaN
# 4               NaN               NaN        NaN             NaN
#
#   AST_interval_f2 AST_diff Alkalinephos_interval_f1 Alkalinephos_interval_f2  \
# 0             NaN      NaN                      NaN                      NaN
# 1             NaN      NaN                      NaN                      NaN
# 2             NaN      NaN                      NaN                      NaN
# 3             NaN      NaN                      NaN                      NaN
# 4             NaN      NaN                      NaN                      NaN
#
#   Alkalinephos_diff BUN_interval_f1 BUN_interval_f2 BUN_diff  \
# 0               NaN             NaN             NaN      NaN
# 1               NaN             NaN             NaN      NaN
# 2               NaN             NaN             NaN      NaN
# 3               NaN             NaN             NaN      NaN
# 4               NaN             NaN             NaN      NaN
#
#   BaseExcess_interval_f1 BaseExcess_interval_f2 BaseExcess_diff  \
# 0                    NaN                    NaN             NaN
# 1                    NaN                    NaN             NaN
# 2                    NaN                    NaN             NaN
# 3                    NaN                    NaN             NaN
# 4                    NaN                    NaN             NaN
#
#   Bilirubin_total_interval_f1 Bilirubin_total_interval_f2  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   Bilirubin_total_diff Calcium_interval_f1 Calcium_interval_f2 Calcium_diff  \
# 0                  NaN                 NaN                 NaN          NaN
# 1                  NaN                 NaN                 NaN          NaN
# 2                  NaN                 NaN                 NaN          NaN
# 3                  NaN                 NaN                 NaN          NaN
# 4                  NaN                 NaN                 NaN          NaN
#
#   Chloride_interval_f1 Chloride_interval_f2 Chloride_diff  \
# 0                  NaN                  NaN           NaN
# 1                  NaN                  NaN           NaN
# 2                  NaN                  NaN           NaN
# 3                  NaN                  NaN           NaN
# 4                  NaN                  NaN           NaN
#
#   Creatinine_interval_f1 Creatinine_interval_f2 Creatinine_diff  \
# 0                    NaN                    NaN             NaN
# 1                    NaN                    NaN             NaN
# 2                    NaN                    NaN             NaN
# 3                    NaN                    NaN             NaN
# 4                    NaN                    NaN             NaN
#
#   FiO2_interval_f1 FiO2_interval_f2 FiO2_diff Glucose_interval_f1  \
# 0              NaN              NaN       NaN                 NaN
# 1              NaN              NaN       NaN                 NaN
# 2              NaN              NaN       NaN                 NaN
# 3              NaN              NaN       NaN                 NaN
# 4              NaN              NaN       NaN                 NaN
#
#   Glucose_interval_f2 Glucose_diff HCO3_interval_f1 HCO3_interval_f2  \
# 0                 NaN          NaN              NaN              NaN
# 1                 NaN          NaN              NaN              NaN
# 2                 NaN          NaN              NaN              NaN
# 3                 NaN          NaN              NaN              NaN
# 4                 NaN          NaN              NaN              NaN
#
#   HCO3_diff Hct_interval_f1 Hct_interval_f2 Hct_diff Hgb_interval_f1  \
# 0       NaN             NaN             NaN      NaN             NaN
# 1       NaN             NaN             NaN      NaN             NaN
# 2       NaN             NaN             NaN      NaN             NaN
# 3       NaN             NaN             NaN      NaN             NaN
# 4       NaN             NaN             NaN      NaN             NaN
#
#   Hgb_interval_f2 Hgb_diff Lactate_interval_f1 Lactate_interval_f2  \
# 0             NaN      NaN                 NaN                 NaN
# 1             NaN      NaN                 NaN                 NaN
# 2             NaN      NaN                 NaN                 NaN
# 3             NaN      NaN                 NaN                 NaN
# 4             NaN      NaN                 NaN                 NaN
#
#   Lactate_diff Magnesium_interval_f1 Magnesium_interval_f2 Magnesium_diff  \
# 0          NaN                   NaN                   NaN            NaN
# 1          NaN                   NaN                   NaN            NaN
# 2          NaN                   NaN                   NaN            NaN
# 3          NaN                   NaN                   NaN            NaN
# 4          NaN                   NaN                   NaN            NaN
#
#   PTT_interval_f1 PTT_interval_f2 PTT_diff PaCO2_interval_f1  \
# 0             NaN             NaN      NaN               NaN
# 1             NaN             NaN      NaN               NaN
# 2             NaN             NaN      NaN               NaN
# 3             NaN             NaN      NaN               NaN
# 4             NaN             NaN      NaN               NaN
#
#   PaCO2_interval_f2 PaCO2_diff PaO2_interval_f1 PaO2_interval_f2 PaO2_diff  \
# 0               NaN        NaN              NaN              NaN       NaN
# 1               NaN        NaN              NaN              NaN       NaN
# 2               NaN        NaN              NaN              NaN       NaN
# 3               NaN        NaN              NaN              NaN       NaN
# 4               NaN        NaN              NaN              NaN       NaN
#
#   Phosphate_interval_f1 Phosphate_interval_f2 Phosphate_diff  \
# 0                   NaN                   NaN            NaN
# 1                   NaN                   NaN            NaN
# 2                   NaN                   NaN            NaN
# 3                   NaN                   NaN            NaN
# 4                   NaN                   NaN            NaN
#
#   Platelets_interval_f1 Platelets_interval_f2 Platelets_diff  \
# 0                   NaN                   NaN            NaN
# 1                   NaN                   NaN            NaN
# 2                   NaN                   NaN            NaN
# 3                   NaN                   NaN            NaN
# 4                   NaN                   NaN            NaN
#
#   Potassium_interval_f1 Potassium_interval_f2 Potassium_diff SaO2_interval_f1  \
# 0                   NaN                   NaN            NaN              NaN
# 1                   NaN                   NaN            NaN              NaN
# 2                   NaN                   NaN            NaN              NaN
# 3                   NaN                   NaN            NaN              NaN
# 4                   NaN                   NaN            NaN              NaN
#
#   SaO2_interval_f2 SaO2_diff Sodium_interval_f1 Sodium_interval_f2  \
# 0              NaN       NaN                NaN                NaN
# 1              NaN       NaN                NaN                NaN
# 2              NaN       NaN                NaN                NaN
# 3              NaN       NaN                NaN                NaN
# 4              NaN       NaN                NaN                NaN
#
#   Sodium_diff WBC_interval_f1 WBC_interval_f2 WBC_diff pH_interval_f1  \
# 0         NaN             NaN             NaN      NaN            NaN
# 1         NaN             NaN             NaN      NaN            NaN
# 2         NaN             NaN             NaN      NaN            NaN
# 3         NaN             NaN             NaN      NaN            NaN
# 4         NaN             NaN             NaN      NaN            NaN
#
#   pH_interval_f2 pH_diff HR_mean O2Sat_mean SBP_mean MAP_mean Resp_mean  \
# 0            NaN     NaN     NaN        NaN      NaN      NaN       NaN
# 1            NaN     NaN     NaN        NaN      NaN      NaN       NaN
# 2            NaN     NaN     NaN        NaN      NaN      NaN       NaN
# 3            NaN     NaN     NaN        NaN      NaN      NaN       NaN
# 4            NaN     NaN     NaN        NaN      NaN      NaN       NaN
#
#   HR_median O2Sat_median SBP_median MAP_median Resp_median HR_min O2Sat_min  \
# 0       NaN          NaN        NaN        NaN         NaN    NaN       NaN
# 1       NaN          NaN        NaN        NaN         NaN    NaN       NaN
# 2       NaN          NaN        NaN        NaN         NaN    NaN       NaN
# 3       NaN          NaN        NaN        NaN         NaN    NaN       NaN
# 4       NaN          NaN        NaN        NaN         NaN    NaN       NaN
#
#   SBP_min MAP_min Resp_min HR_max O2Sat_max SBP_max MAP_max Resp_max HR_std  \
# 0     NaN     NaN      NaN    NaN       NaN     NaN     NaN      NaN    NaN
# 1     NaN     NaN      NaN    NaN       NaN     NaN     NaN      NaN    NaN
# 2     NaN     NaN      NaN    NaN       NaN     NaN     NaN      NaN    NaN
# 3     NaN     NaN      NaN    NaN       NaN     NaN     NaN      NaN    NaN
# 4     NaN     NaN      NaN    NaN       NaN     NaN     NaN      NaN    NaN
#
#   O2Sat_std SBP_std MAP_std Resp_std HR_dstd O2Sat_dstd SBP_dstd MAP_dstd  \
# 0       NaN     NaN     NaN      NaN     NaN        NaN      NaN      NaN
# 1       NaN     NaN     NaN      NaN     NaN        NaN      NaN      NaN
# 2       NaN     NaN     NaN      NaN     NaN        NaN      NaN      NaN
# 3       NaN     NaN     NaN      NaN     NaN        NaN      NaN      NaN
# 4       NaN     NaN     NaN      NaN     NaN        NaN      NaN      NaN
#
#   Resp_dstd HR_score Temp_score Resp_score MAP_score Creatinine_score qsofa  \
# 0       NaN      NaN        NaN        NaN       NaN              NaN   NaN
# 1       NaN      NaN        NaN        NaN       NaN              NaN   NaN
# 2       NaN      NaN        NaN        NaN       NaN              NaN   NaN
# 3       NaN      NaN        NaN        NaN       NaN              NaN   NaN
# 4       NaN      NaN        NaN        NaN       NaN              NaN   NaN
#
#   Platelets_score Bilirubin_score SIRS
# 0             NaN             NaN  NaN
# 1             NaN             NaN  NaN
# 2             NaN             NaN  NaN
# 3             NaN             NaN  NaN
# 4             NaN             NaN  NaN

# %% [markdown]
# ### 1.3 & 1.4 & 1.5
# - Resample sparse matrix to hourly longitudinal data
# - Aggregate data into 3 hour bins with 6 hour sliding window (median)
# - Static merge

# %%
test_data = test_data[["csn", "pat_id", "recorded_time", "hospital_admission_date_time"] + total_feature_list[:36]].copy()

# %%
test_data = run(test_data)
keep_csns = list(test_data.csn.unique())

# %%
test_data.loc[:, ~test_data.columns.isin(hide)].head(5)
# Out:
#     los  rel_time       HR   O2Sat    Temp      SBP     DBP     MAP    Resp  \
# 68    0    6.0000  91.5000 98.0000 36.7000 134.0000 83.0000 98.0000 15.0000
# 67    6   11.0000  91.5000 98.0000 36.7000 134.0000 83.0000 98.0000 15.0000
# 64   12   18.0000 122.0000 97.0000 36.7000 120.0000 74.0000 90.0000 18.0000
# 59   12   18.0000  69.0000 99.0000 37.1000 111.5000 68.5000 78.5000 18.0000
# 25   15   23.0000  81.5000 98.0000 36.6000 124.0000 76.0000 89.5000 16.0000
#
#     EtCO2     AST  Alkalinephos     BUN  BaseExcess  Bilirubin_total  Calcium  \
# 68 2.0000 12.0000       82.0000 17.0000         nan           0.5000   9.8000
# 67 2.0000 34.0000       57.0000 30.0000         nan           0.7000   7.8000
# 64 2.0000 72.0000      798.0000 20.0000         nan           2.7000   7.4000
# 59 2.0000 11.0000      155.0000 40.0000         nan           0.5000   8.5000
# 25 2.0000     nan           nan 22.0000         nan              nan   8.9000
#
#     Chloride  Creatinine  FiO2  Glucose    HCO3     Hct     Hgb  Lactate  \
# 68  106.0000      0.7400   nan  98.0000 22.3000 39.1000 12.8000      nan
# 67  106.0000      1.9600   nan 114.0000 22.3000 30.3000  9.7000      nan
# 64  107.0000      0.6300   nan 113.0000 22.3000 19.7000  6.0000      nan
# 59  106.0000      1.3200   nan 346.0000 22.3000 23.3000  7.8000      nan
# 25  106.0000      0.7800   nan  88.0000     nan 40.7000 14.1000      nan
#
#     Magnesium     PTT   PaCO2    PaO2  Phosphate  Platelets  Potassium  SaO2  \
# 68     2.1000 29.7000 29.0000 95.0000     3.6000   218.0000     4.2000   nan
# 67     1.7000 29.7000 29.0000 95.0000     3.6000   151.0000     4.5000   nan
# 64     1.7000 29.7000 29.0000 95.0000     3.6000   159.0000     3.8000   nan
# 59     1.6000 29.7000 29.0000 95.0000     3.6000   216.0000     4.0000   nan
# 25     1.9000     nan     nan     nan     3.6000   224.0000     4.3000   nan
#
#      Sodium     WBC     pH  gcs_total_score  is_female  HR_interval_f1  \
# 68 141.0000  5.6000 7.5100          15.0000          1          0.0000
# 67 140.0000 14.6000 7.5100          15.0000          0          1.0000
# 64 139.0000  7.0000 7.5100          15.0000          0          1.0000
# 59 133.0000  7.5000 7.5100          15.0000          0          4.0000
# 25 140.0000  7.9000    nan          15.0000          0          6.0000
#
#     HR_interval_f2  HR_diff  O2Sat_interval_f1  O2Sat_interval_f2  O2Sat_diff  \
# 68         -1.0000  -6.0000             0.0000            -1.0000      0.0000
# 67          0.0000  -6.0000             1.0000             0.0000      0.0000
# 64          0.0000  -6.0000             1.0000             0.0000      0.0000
# 59          0.0000  -6.0000             2.0000             1.0000      0.0000
# 25          0.0000   0.0000             5.0000             0.0000      0.0000
#
#     Temp_interval_f1  Temp_interval_f2  Temp_diff  SBP_interval_f1  \
# 68            0.0000           -1.0000    -0.3000           0.0000
# 67            0.0000           -1.0000    -0.3000           1.0000
# 64            1.0000            0.0000    -0.3000           1.0000
# 59            4.0000            0.0000    -0.3000           4.0000
# 25            4.0000            0.0000     0.0000           6.0000
#
#     SBP_interval_f2  SBP_diff  MAP_interval_f1  MAP_interval_f2  MAP_diff  \
# 68          -1.0000    9.5000           0.0000          -1.0000    8.5000
# 67           0.0000    9.5000           1.0000           0.0000    8.5000
# 64           0.0000    9.5000           1.0000           0.0000    8.5000
# 59           0.0000    9.5000           4.0000           0.0000    8.5000
# 25           0.0000    0.0000           6.0000           0.0000    0.0000
#
#     DBP_interval_f1  DBP_interval_f2  DBP_diff  Resp_interval_f1  \
# 68           0.0000          -1.0000    9.0000            0.0000
# 67           1.0000           0.0000    9.0000            1.0000
# 64           1.0000           0.0000    9.0000            1.0000
# 59           4.0000           0.0000    9.0000            0.0000
# 25           6.0000           0.0000    0.0000            6.0000
#
#     Resp_interval_f2  Resp_diff  EtCO2_interval_f1  EtCO2_interval_f2  \
# 68           -1.0000     0.0000             0.0000            -1.0000
# 67            0.0000     0.0000             0.0000            -1.0000
# 64            0.0000     0.0000             0.0000            -1.0000
# 59           -1.0000     0.0000             0.0000            -1.0000
# 25            0.0000     0.0000             0.0000            -1.0000
#
#     EtCO2_diff  AST_interval_f1  AST_interval_f2  AST_diff  \
# 68      0.0000           1.0000           0.0000   -5.0000
# 67      0.0000           3.0000           0.0000   -5.0000
# 64      0.0000           4.0000           0.0000    0.0000
# 59      0.0000           2.0000           3.0000    0.0000
# 25      0.0000           0.0000          -1.0000       nan
#
#     Alkalinephos_interval_f1  Alkalinephos_interval_f2  Alkalinephos_diff  \
# 68                    1.0000                    0.0000             1.0000
# 67                    3.0000                    0.0000             1.0000
# 64                    4.0000                    0.0000             0.0000
# 59                    2.0000                    3.0000             0.0000
# 25                    0.0000                   -1.0000                nan
#
#     BUN_interval_f1  BUN_interval_f2  BUN_diff  BaseExcess_interval_f1  \
# 68           1.0000           0.0000    0.5000                  0.0000
# 67           3.0000           0.0000    0.5000                  0.0000
# 64           4.0000           0.0000    0.0000                  0.0000
# 59           4.0000           0.0000    0.0000                  0.0000
# 25           0.0000          -1.0000    0.0000                  0.0000
#
#     BaseExcess_interval_f2  BaseExcess_diff  Bilirubin_total_interval_f1  \
# 68                      -1              nan                       1.0000
# 67                      -1              nan                       3.0000
# 64                      -1              nan                       4.0000
# 59                      -1              nan                       2.0000
# 25                      -1              nan                       0.0000
#
#     Bilirubin_total_interval_f2  Bilirubin_total_diff  Calcium_interval_f1  \
# 68                       0.0000                0.0000               1.0000
# 67                       0.0000                0.0000               3.0000
# 64                       0.0000                0.0000               4.0000
# 59                       3.0000                0.0000               4.0000
# 25                      -1.0000                   nan               0.0000
#
#     Calcium_interval_f2  Calcium_diff  Chloride_interval_f1  \
# 68               0.0000        0.0000                1.0000
# 67               0.0000        0.0000                3.0000
# 64               0.0000        0.0000                4.0000
# 59               0.0000        0.0000                4.0000
# 25              -1.0000        0.0000                0.0000
#
#     Chloride_interval_f2  Chloride_diff  Creatinine_interval_f1  \
# 68                0.0000         0.5000                  1.0000
# 67                0.0000         0.5000                  3.0000
# 64                0.0000         0.0000                  4.0000
# 59                0.0000         0.0000                  4.0000
# 25               -1.0000         0.0000                  0.0000
#
#     Creatinine_interval_f2  Creatinine_diff  FiO2_interval_f1  \
# 68                  0.0000          -0.0300            0.0000
# 67                  0.0000          -0.0300            0.0000
# 64                  0.0000           0.0000            0.0000
# 59                  0.0000           0.0000            0.0000
# 25                 -1.0000           0.0000            0.0000
#
#     FiO2_interval_f2  FiO2_diff  Glucose_interval_f1  Glucose_interval_f2  \
# 68                -1        nan               1.0000               0.0000
# 67                -1        nan               3.0000               0.0000
# 64                -1        nan               4.0000               0.0000
# 59                -1        nan               4.0000               0.0000
# 25                -1        nan               0.0000              -1.0000
#
#     Glucose_diff  HCO3_interval_f1  HCO3_interval_f2  HCO3_diff  \
# 68       -2.5000            0.0000           -1.0000     0.0000
# 67       -2.5000            0.0000           -1.0000     0.0000
# 64        0.0000            0.0000           -1.0000     0.0000
# 59        0.0000            0.0000           -1.0000     0.0000
# 25        0.0000            0.0000           -1.0000        nan
#
#     Hct_interval_f1  Hct_interval_f2  Hct_diff  Hgb_interval_f1  \
# 68           1.0000           0.0000    0.0000           1.0000
# 67           2.0000           0.0000    0.0000           2.0000
# 64           4.0000           0.0000    0.0000           4.0000
# 59           4.0000           0.0000    0.0000           4.0000
# 25           0.0000          -1.0000    0.0000           0.0000
#
#     Hgb_interval_f2  Hgb_diff  Lactate_interval_f1  Lactate_interval_f2  \
# 68           0.0000    0.0000               0.0000                   -1
# 67           0.0000    0.0000               0.0000                   -1
# 64           0.0000    0.0000               0.0000                   -1
# 59           0.0000    0.0000               0.0000                   -1
# 25          -1.0000    0.0000               0.0000                   -1
#
#     Lactate_diff  Magnesium_interval_f1  Magnesium_interval_f2  \
# 68           nan                 1.0000                 0.0000
# 67           nan                 0.0000                -1.0000
# 64           nan                 2.0000                 0.0000
# 59           nan                 2.0000                 0.0000
# 25           nan                 0.0000                -1.0000
#
#     Magnesium_diff  PTT_interval_f1  PTT_interval_f2  PTT_diff  \
# 68          0.0000           0.0000          -1.0000    0.0000
# 67          0.0000           0.0000          -1.0000    0.0000
# 64          0.0000           0.0000          -1.0000    0.0000
# 59          0.0000           2.0000           0.0000    0.0000
# 25          0.0000           0.0000          -1.0000       nan
#
#     PaCO2_interval_f1  PaCO2_interval_f2  PaCO2_diff  PaO2_interval_f1  \
# 68             0.0000            -1.0000      0.0000            0.0000
# 67             0.0000            -1.0000      0.0000            0.0000
# 64             0.0000            -1.0000      0.0000            0.0000
# 59             0.0000            -1.0000      0.0000            0.0000
# 25             0.0000            -1.0000         nan            0.0000
#
#     PaO2_interval_f2  PaO2_diff  Phosphate_interval_f1  Phosphate_interval_f2  \
# 68           -1.0000     0.0000                 0.0000                -1.0000
# 67           -1.0000     0.0000                 0.0000                -1.0000
# 64           -1.0000     0.0000                 0.0000                -1.0000
# 59           -1.0000     0.0000                 0.0000                -1.0000
# 25           -1.0000        nan                 0.0000                -1.0000
#
#     Phosphate_diff  Platelets_interval_f1  Platelets_interval_f2  \
# 68          0.0000                 1.0000                 0.0000
# 67          0.0000                 2.0000                 0.0000
# 64          0.0000                 4.0000                 0.0000
# 59          0.0000                 4.0000                 0.0000
# 25          0.0000                 0.0000                -1.0000
#
#     Platelets_diff  Potassium_interval_f1  Potassium_interval_f2  \
# 68          0.0000                 1.0000                 0.0000
# 67          0.0000                 3.0000                 0.0000
# 64          0.0000                 4.0000                 0.0000
# 59          0.0000                 4.0000                 0.0000
# 25          0.0000                 0.0000                -1.0000
#
#     Potassium_diff  SaO2_interval_f1  SaO2_interval_f2  SaO2_diff  \
# 68         -0.3000            0.0000                -1        nan
# 67         -0.3000            0.0000                -1        nan
# 64          0.0000            0.0000                -1        nan
# 59          0.0000            0.0000                -1        nan
# 25          0.0000            0.0000                -1        nan
#
#     Sodium_interval_f1  Sodium_interval_f2  Sodium_diff  WBC_interval_f1  \
# 68              1.0000              0.0000       0.5000           1.0000
# 67              3.0000              0.0000       0.5000           2.0000
# 64              4.0000              0.0000       0.0000           4.0000
# 59              4.0000              0.0000       0.0000           4.0000
# 25              0.0000             -1.0000       0.0000           0.0000
#
#     WBC_interval_f2  WBC_diff  pH_interval_f1  pH_interval_f2  pH_diff  \
# 68           0.0000    0.0000          0.0000         -1.0000   0.0000
# 67           0.0000    0.0000          0.0000         -1.0000   0.0000
# 64           0.0000    0.0000          0.0000         -1.0000   0.0000
# 59           0.0000    0.0000          0.0000         -1.0000   0.0000
# 25          -1.0000    0.0000          0.0000         -1.0000      nan
#
#     HR_mean  O2Sat_mean  SBP_mean  MAP_mean  Resp_mean  HR_median  \
# 68  91.5000     98.0000  134.0000   98.0000    15.0000    91.5000
# 67 111.8333     97.3333  124.6667   92.6667    17.0000   122.0000
# 64  79.6000     98.6000  113.2000   80.8000    18.0000    69.0000
# 59  79.6000     99.0000  111.5000   82.4000    18.0000    80.0000
# 25  85.5000     98.0000  132.7500   98.0000    15.7500    85.0000
#
#     O2Sat_median  SBP_median  MAP_median  Resp_median  HR_min  O2Sat_min  \
# 68       98.0000    134.0000     98.0000      15.0000 91.5000    98.0000
# 67       97.0000    120.0000     90.0000      18.0000 91.5000    97.0000
# 64       99.0000    111.5000     78.5000      18.0000 69.0000    97.0000
# 59       99.0000    103.0000     80.5000      18.0000 69.0000    99.0000
# 25       98.0000    129.7500     97.5000      16.0000 81.5000    98.0000
#
#     SBP_min  MAP_min  Resp_min   HR_max  O2Sat_max  SBP_max  MAP_max  \
# 68 134.0000  98.0000   15.0000  91.5000    98.0000 134.0000  98.0000
# 67 120.0000  90.0000   15.0000 122.0000    98.0000 134.0000  98.0000
# 64 111.5000  78.5000   18.0000 122.0000    99.0000 120.0000  90.0000
# 59 101.0000  70.0000   18.0000  89.0000    99.0000 140.0000  94.0000
# 25 124.0000  89.5000   14.0000  93.0000    98.0000 145.0000 112.0000
#
#     Resp_max  HR_std  O2Sat_std  SBP_std  MAP_std  Resp_std  HR_dstd  \
# 68   15.0000     nan        nan      nan      nan       nan      nan
# 67   18.0000 17.6092     0.5774   8.0829   4.6188    1.7321      nan
# 64   18.0000 23.7023     0.8944   3.8013   5.1430    0.0000      nan
# 59   18.0000  7.9246     0.0000  16.4697   9.3635    0.0000      nan
# 25   17.0000  4.3704     0.0000   9.4644   8.5965    1.0840   6.8099
#
#     O2Sat_dstd  SBP_dstd  MAP_dstd  Resp_dstd  HR_score  Temp_score  \
# 68         nan       nan       nan        nan    1.0000      1.0000
# 67         nan       nan       nan        nan    1.0000      1.0000
# 64         nan       nan       nan        nan    2.0000      1.0000
# 59         nan       nan       nan        nan    0.0000      1.0000
# 25      0.4082    9.0425    5.0662     0.9832    0.0000      1.0000
#
#     Resp_score  MAP_score  Creatinine_score  qsofa  Platelets_score  \
# 68      0.0000     0.0000            0.0000 0.0000           0.0000
# 67      0.0000     0.0000            1.0000 0.0000           0.0000
# 64      0.0000     0.0000            0.0000 0.0000           0.0000
# 59      0.0000     0.0000            1.0000 0.0000           0.0000
# 25      0.0000     0.0000            0.0000 0.0000           0.0000
#
#     Bilirubin_score   SIRS
# 68           0.0000  False
# 67           0.0000   True
# 64           2.0000  False
# 59           0.0000  False
# 25              nan  False

# %%
# vm = True if running in VM
test_data = ml.preprocess(test_data, vm = False)
test_data = test_data.sort_values("rel_time", ascending = True).drop_duplicates(subset = ["csn", "pat_id"], keep = "last")
#test_data = test_data[total_feature_list]
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# Extracting informative features
# 100%|██████████| 12/12 [00:06<00:00,  1.82it/s]
# Completed Extracting informative features
# Extracting Rolling features
# Completed Extracting Rolling features
# Extracting Score Features
# Completed Extracting Score Features
# Preprocessing completed with total of 178 features

# %%
len(test_data.columns)
# Out:
# 178

# %%
# Out:
# 40

# %% [markdown]
# ## 2. TEST

# %%
test_set = list(test_data.csn.unique())
model_path = args.model_dir
drop_features = ['pat_id', 'csn', 'los', 'rel_time']

current_time_formatted = str(current_time.tz_localize("US/Eastern"))
current_time_formatted = current_time_formatted.replace(' ', 'T')

result = ml.predict(test_set, test_data, model_path, 0.48, vm = False, drop_features = drop_features, hist_data = hist_data, current_time = current_time_formatted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-8d69b9559168> in <module>()
#       1 test_set = list(test_data.csn.unique())
# ----> 2 model_path = args.model_dir
#       3 drop_features = ['pat_id', 'csn', 'los', 'rel_time']
#       4
#       5 current_time_formatted = str(current_time.tz_localize("US/Eastern"))
#
# NameError: name 'args' is not defined

# %% [markdown]
# ## 3. Historical Test Output

# %%
url_output = 'https://prd-rta-app01.eushc.org:8443/ords/rta/sepsisml/outputcache'
historical_output = connect(url_output, username, password)
historical_output = historical_output.dropna(subset = ["run_date", "predictedprobability"])
 
if len(historical_output) >0 :
    historical_output = historical_output.sort_values(by = "run_date", ascending = True)
    historical_output = historical_output[["csn", "pat_id", "predictedprobability", "run_date"]]
        
    historical_output = historical_output.dropna().drop_duplicates(subset = ["csn", "pat_id"], keep = "last")
    historical_output = historical_output.rename(columns = {"predictedprobability": "PastProbability", "run_date": "PastRunDate"})

    historical_output["PastRunDate"] = pd.to_datetime(historical_output["PastRunDate"])
    historical_output["PastRunDate"] = historical_output["PastRunDate"].dt.tz_convert('US/Eastern')
    historical_output["PastRunDate"] = historical_output["PastRunDate"].dt.tz_localize(None)
    historical_output["pat_id"] = pd.to_numeric(historical_output["pat_id"], errors='coerce')
    historical_output["csn"] = pd.to_numeric(historical_output["csn"], errors='coerce')
    historical_output["PastProbability"] = pd.to_numeric(historical_output["PastProbability"], errors='coerce')
    historical_output = historical_output[historical_output.csn.isin(keep_csns)]
else:
    historical_output = pd.DataFrame(columns = {"csn", "pat_id", "PastProbability", "PastRunDate"})
    historical_output["csn"] = pd.Series(keep_csns)


    #historical_output.to_csv("hist_data.csv")
print("hist_data_saved")

# %% [markdown]
# ## 4. Output to Output Table

# %%
result = result.merge(historical_output, on = ["csn", "pat_id"], how = "left")
#result.to_csv("result_debug.csv", index = False)
result["PastProbability"] = pd.to_numeric(result["PastProbability"]) 
result["prob_diff"] = round((result["PredictedProbability"] - result["PastProbability"])*100, 2)
    
result["PreviousAlert"] = round(result["PastProbability"] * 100, 2).astype(str) + '% ' + (result["prob_diff"]).map('({0:+}%)'.format)
    
    
result["run_date_relative"] = result["rel_time"]
    
result["run_date"] = current_time
result["past_curr_diff"] = (result["run_date"] - pd.to_datetime(result["PastRunDate"])).dt.total_seconds()/3600
    
result["PastRunDate"] = result["PastRunDate"].astype(str)
result["PastRunDate"] = result["PastRunDate"].str.replace(' ', 'T')
result["run_date"] = current_time_formatted
                                       
result["PriorAlertTime"] = result["PastRunDate"] + " " + (result["past_curr_diff"]).map('({:,.2f} hrs ago)'.format)
result = result.drop(["past_curr_diff", "prob_diff", "PastRunDate", "PastProbability"], axis = 1)
result = result.rename(columns = {"PreviousAlert": "previousalert", "PriorAlertTime": "prioralerttime"})
result = result.drop(["ranked_shap"], axis = 1)
  
output = result.to_dict(orient='records')
    
url_output = 'https://prd-rta-app01.eushc.org:8443/ords/rta/sepsisml/outputcache'
    
for i_output in output:
    upload(url_output, username, password, json.dumps(i_output))

# %%
logname = "sepsis_ml_execution.log"
logging.basicConfig(filename=logname,
                    filemode='a',
                    format='%(asctime)s.%(msecs)03d %(levelname)s %(module)s - %(funcName)s: %(message)s',
                        datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.DEBUG)

logging.info("Result Outputed")


print("result outputed")
